# %%
# %run functions.ipynb

# %%
import geopandas as gpd
import pandas as pd
import os

# %%
# schema
col_names = {
    'Name': 'ParkRideName',
    'Description': 'HTMLMetaData',
    'geometry': 'geometry' # don't mess with this - core part of gpd geodataframe
}

# load stations dataframe
filepath = '..\\data\\bronze\\CTA_ParkRide.kml'
gdf = gpd.read_file(filepath).rename(columns=col_names)

print('Loaded', len(gdf), 'rows')
display(gdf.head())
# Out:
# Loaded 17 rows
#               ParkRideName                                       HTMLMetaData  \
# 0               Cumberland  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 1           Midway Airport  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 2  Garfield-South Elevated  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 3                  Kimball  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 4              54th/Cermak  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
#
#                          geometry
# 0  POINT Z (-87.83747 41.98337 0)
# 1  POINT Z (-87.73935 41.78521 0)
# 2  POINT Z (-87.61875 41.79568 0)
# 3  POINT Z (-87.71251 41.96704 0)
# 4  POINT Z (-87.75739 41.85178 0)

# %%
# extract metadata from the html column
metadata_items = [
    'Rail Station', 
    'Rail Line', 
    'ADA',
    'Spaces'
]

gdf['ExtractedMetaData'] = gdf.HTMLMetaData.apply(extract_metadata)

display(gdf.head())
# Out:
#               ParkRideName                                       HTMLMetaData  \
# 0               Cumberland  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 1           Midway Airport  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 2  Garfield-South Elevated  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 3                  Kimball  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 4              54th/Cermak  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
#
#                          geometry  \
# 0  POINT Z (-87.83747 41.98337 0)
# 1  POINT Z (-87.73935 41.78521 0)
# 2  POINT Z (-87.61875 41.79568 0)
# 3  POINT Z (-87.71251 41.96704 0)
# 4  POINT Z (-87.75739 41.85178 0)
#
#                                  ExtractedMetaData
# 0              [Cumberland, Blue Line, Yes, 1,633]
# 1          [Midway Airport, Orange Line, Yes, 299]
# 2  [Garfield-South Elevated, Green Line, Yes, 117]
# 3                   [Kimball, Brown Line, Yes, 73]
# 4               [54th/Cermak, Pink Line, Yes, 175]

# %%
# explode the metadata out into columns
new_columns = ['StationName', 'RailLine', 'ADAAccessible', 'Spaces']

metadata_col = gdf.ExtractedMetaData
for i, col in enumerate(new_columns):
    gdf[col] = metadata_col.str[i]

display(gdf.head())
# Out:
#               ParkRideName                                       HTMLMetaData  \
# 0               Cumberland  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 1           Midway Airport  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 2  Garfield-South Elevated  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 3                  Kimball  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 4              54th/Cermak  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
#
#                          geometry  \
# 0  POINT Z (-87.83747 41.98337 0)
# 1  POINT Z (-87.73935 41.78521 0)
# 2  POINT Z (-87.61875 41.79568 0)
# 3  POINT Z (-87.71251 41.96704 0)
# 4  POINT Z (-87.75739 41.85178 0)
#
#                                  ExtractedMetaData              StationName  \
# 0              [Cumberland, Blue Line, Yes, 1,633]               Cumberland
# 1          [Midway Airport, Orange Line, Yes, 299]           Midway Airport
# 2  [Garfield-South Elevated, Green Line, Yes, 117]  Garfield-South Elevated
# 3                   [Kimball, Brown Line, Yes, 73]                  Kimball
# 4               [54th/Cermak, Pink Line, Yes, 175]              54th/Cermak
#
#       RailLine ADAAccessible Spaces
# 0    Blue Line           Yes  1,633
# 1  Orange Line           Yes    299
# 2   Green Line           Yes    117
# 3   Brown Line           Yes     73
# 4    Pink Line           Yes    175

# %%
# convert spaces to an int type
gdf['Spaces'] = gdf.Spaces.str.replace(',', '').astype(int)

display(gdf.head())
# Out:
#               ParkRideName                                       HTMLMetaData  \
# 0               Cumberland  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 1           Midway Airport  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 2  Garfield-South Elevated  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 3                  Kimball  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
# 4              54th/Cermak  <html xmlns:fo="http://www.w3.org/1999/XSL/For...
#
#                          geometry  \
# 0  POINT Z (-87.83747 41.98337 0)
# 1  POINT Z (-87.73935 41.78521 0)
# 2  POINT Z (-87.61875 41.79568 0)
# 3  POINT Z (-87.71251 41.96704 0)
# 4  POINT Z (-87.75739 41.85178 0)
#
#                                  ExtractedMetaData              StationName  \
# 0              [Cumberland, Blue Line, Yes, 1,633]               Cumberland
# 1          [Midway Airport, Orange Line, Yes, 299]           Midway Airport
# 2  [Garfield-South Elevated, Green Line, Yes, 117]  Garfield-South Elevated
# 3                   [Kimball, Brown Line, Yes, 73]                  Kimball
# 4               [54th/Cermak, Pink Line, Yes, 175]              54th/Cermak
#
#       RailLine ADAAccessible  Spaces
# 0    Blue Line           Yes    1633
# 1  Orange Line           Yes     299
# 2   Green Line           Yes     117
# 3   Brown Line           Yes      73
# 4    Pink Line           Yes     175

# %%
# drop no longer needed columns
select_cols = [
    'ParkRideName',
    'geometry',
    'StationName',
    'RailLine',
    'ADAAccessible',
    'Spaces'
]
gdf = gdf[select_cols]

# save to file
filepath = '..\\data\\silver\\'
filename = 'DimParkRide.parquet'
gdf.to_parquet(filepath+filename)

# verify
os.listdir(filepath)
# Out:
# ['DimParkRide.parquet', 'DimRailLine.parquet', 'DimRailStation.parquet']
